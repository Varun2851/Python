# %%
a = 10
b = 20
print("The value of a is {} and b is {}".format(a,b))
# Out:
# The value of a is 10 and b is 20

# %%
a = 10
b = 20
print("The value of a is {1} and b is {0}".format(a,b))
# Out:
# The value of a is 20 and b is 10

# %%
name = "Varun"
greetings = "Good mornig"

print("Hello {} , {}".format(greetings , name))
# Out:
# Hello Good mornig , Varun

# %%
no1 = 200
no2 = 100

add = no1+no2
sub = no1-no2
mul = no1*no2
div = no1/no2
f_div = no1//no2

print("a+b={}".format(add))
print("a-b={}".format(sub))
print("a*b={}".format(mul))
print("a/b={}".format(div))
print("a//b={}".format(f_div))
# Out:
# a+b=300
# a-b=100
# a*b=20000
# a/b=2.0
# a//b=2

# %%
##larning about arithmatic operator

no1 = 20
no2 = 40

add = no1+no2
print("a+b={}".format(add))
sub = no1-no2
print("a-b={}".format(sub))
mul = no1*no2
print("a*b={}".format(mul))
div = int(no1/no2) ##typecast
print("a/b={}".format(div))
doubleDivide = no1//no2
print("a//b={}".format(doubleDivide))
# Out:
# a+b=60
# a-b=-20
# a*b=800
# a/b=0
# a//b=0

# %%
print(no1,no2)
# Out:
# 20 40

# %%
print(no1>no2)
print(no1<no2)
print(no1==no2)
print(no1<=no2)
print(no1 == no1)
print(no1 != no2)
# Out:
# False
# True
# False
# True
# True
# True

# %%
(10 == 10) or (12==12)
# Out:
# True

# %%
not( (10 != 5) and (5>7))
# Out:
# True

# %%
10 & 4
# Out:
# 0

# %%
10 | 4
# Out:
# 14

# %%
bin(14)
# Out:
# '0b1110'

# %%
4^4 # same ^ same will return 0
# same ^ different will return 1
# Out:
# 0

# %%
a = 5 # assigning value 5 to a
a = a + 1
print(a)
# Out:
# 6

# %%
a += 2
print(a)
# Out:
# 8

# %%
a,b,c = "ML",34. 0.3 # multipe Assignment
a = b = c = 19 #multiple assignment with same value

# %%
my_str = "GoodMorning"
"Good" in my_str # in operator check weather Good is present int my_str or not
# Out:
# True

# %%
n1 = 5000
n2 = 300
id(n1)
# Out:
# 140485620143088
